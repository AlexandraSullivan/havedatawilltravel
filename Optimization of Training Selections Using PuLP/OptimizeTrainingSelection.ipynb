# %% [markdown]
# # Optimization of Training Selections Using PuLP

# %% [markdown]
# <i>What you can learn from this post:
# - How to formulate a simple optimization into mathematical formulas
# - Using the Python PuLP package to solve a simple optimization
# - An analytical approach we use to organize an internal event
# </i>
#
#
# Target audience: technical, but learning (like us!)

# %% [markdown]
# ## Problem Introduction

# %% [markdown]
# Our Analytics department places high value on continuous learning and development. That's why we decided that our 2015 department summit would include break-out training sessions as a part of the fun. But how would we best decide which fun and exciting things to learn more about, and who to assign to each training? Well, this seemed like a fun sample problem for learning about optimization!

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# The first step was to design a survey. The planning committee identified six potential training topics that could be prepared by people in our department, of which we would choose three based on the survey results:
#
# * Model Statistics with R (R Stats)
# * Introduction to Simulation (Sim)
# * Using Public APIs (APIs)
# * Introduction to Python (Python)
# * Data Visualization (Viz)
# * Introduction to NLP (NLP)
#
# We used Survey Monkey to create a simple survey asking everyone in the department to rank their preferences (or check "Not Interested").

# %% [markdown]
# ![survey image - link not working](survey_choices_image.png)

# %% [markdown]
# We manually extracted the survey results to create a csv file with one row per person (30 total rows) with the rank for each course (or NI for "Not Interested"):
#
# ID |Name  | R Stats | Sim | APIs | Python | Viz | NLP
# ---|----- | ------- | --- | ---- | ------ | --- |
# 01 |Alice | 1       | 4   | NI   | 2      | NI  | 3
# 02 |Bob   | 4       | 6   | 3    | 2      | 1   | 5
# ...|...   | ...       | ...   | ...    | ...      | ...   | ...

# %% [markdown]
# ## Determining Our Model

# %% [markdown]
# In the ideal world, everyone would be assigned to their first choice course, but with the variety of interests across our group, this was not be possible. In the absense of giving everyone their first choice, we would instead attempt to assign everyone to their most prefered course given a set of contraints. This gives us the objective of the optimization, which can be written in mathy form as:
#
# $$
#     \\
#     \underset{x,y}{\text{minimize}}
#     \sum\limits_{workshops} \sum\limits_{students} preference \centerdot x_{student,workshop} \\
# $$
# where <i>x<sub>s,w</sub></i> is a binary (0 or 1) decision variable to decide whether student <i>s</i> is assigned to workshop <i>w</i>. Note this is a minimization because lower rank indicates more preference (i.e. rank=1 indicates the student's top choice).

# %% [markdown]
# The first substantive constraint we want to add is to limit the number of open workshops to three. To do this, we will add another binary variable <i>y<sub>w</sub></i> to indicate whether workshop w is open (1) or closed (0). Our constraints to ensure we have only three workshops are:
#
# $$
#     \ Total \ workshops: \ \ \ \sum\limits_{workshops} y_{workshop} = 3 \\
#     \ Only \ valid \ workshops: \ \ \ x_{student,workshop} \leq y_{workshop} \ \ \forall \ \ students, workshops \\
# $$

# %% [markdown]
# The next constraint we want to address is the number of students per workshop. We don't want to have one of the workshop leaders preparing a course for just one or two students. To ensure things are even, we set a lower bound on the number of students per open workshop to seven, as follows:
#
# $$
#     \ Min \ students \ per \ workshop: \ \ \ \sum\limits_{students} x_{student,workshop} \geq 7 y_{workshop} \ \ \forall \ \ workshops \\
# $$

# %% [markdown]
# The remaining constraints are things that are common sense to us, but might not be common sense to the computer. First, we need to tell the computer that <i>x</i> and <i>u</i> are binary variables, as mentioned earlier:
#
# $$
#     \ x_{student,workshop} \ , \ y_{workshop} \ \ \in \ \ \{0,1\} \ \ \forall \ \ students, workshops \\
# $$
#
# And lastly, we want to make sure that each student is attending exactly one workshop:
#
# $$
#     \sum\limits_{workshops} x_{student,workshop} = 1 \ \ \forall \ \ students \\
# $$

# %% [markdown]
# The full model is summarized below.

# %% [markdown]
# ### Final Model

# %% [markdown]
# Objective:
#
# $$
#     \\
#     \underset{x,y}{\text{minimize}}
#     \sum\limits_{workshops} \ \sum\limits_{students} preference \centerdot x_{student,workshop} \\
# $$

# %% [markdown]
# Subject to:
# $$
#     (1) \ Binary \ variables: \ \ \ x_{student,workshop} \ , \ y_{workshop} \ \ \in \ \ \{0,1\} \ \ \forall \ \ students, workshops \\
#     (2) \ Total \ workshops: \ \ \ \sum\limits_{workshops} y_{workshop} = 3 \\
#     (3) \ Workshops \ per \ student: \ \ \ \sum\limits_{workshops} x_{student,workshop} = 1 \ \ \forall \ \ students \\
#     \\
#     (4) \ Min \ students \ per \ workshop: \ \ \ \sum\limits_{students} x_{student,workshop} \geq 7 y_{workshop} \ \ \forall \ \ workshops \\
#     \\
#     (5) \ Only \ valid \ workshops: \ \ \ x_{student,workshop} \leq y_{workshop} \ \ \forall \ \ students, workshops \\
# $$

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# We have a model, we have data - are we ready to start coding? Not quite. Before we can start coding, we have a little data cleaning to do.
#
# Remember those pesky NI's in our dataset? Our code will not know how to handle those in numeric fields. Since our inclination is to not put anyone into a workshop that they have no interest in, we can replace these NI entries with some big number. We chose 100. For our previous sample data, that update resulted in:
#
#
# ID |Name  | R Stats | Sim | APIs | Python | Viz | NLP
# ---|----- | ------- | --- | ---- | ------ | --- |
# 01 |Alice | 1       | 4   | 100  | 2      | 100 | 3
# 02 |Bob   | 4       | 6   | 3    | 2      | 1   | 5
# ...|...   | ...       | ...   | ...    | ...      | ...   | ...
#
# Another complication is that these workshops would be prepared by people in our department - meaning, that there are six workshop-person combinations that are actually that person ranking their interest in taking their own workshop. To simplify, and ensure that all workshop leaders are assigned to their own workshop (if it is open), we gave a rank of 0 to any workshop that a person was the leader of. For example, if Alice was the potential instructor for the Viz workshop, that update would result in:
#
# ID |Name  | R Stats | Sim | APIs | Python | Viz | NLP
# ---|----- | ------- | --- | ---- | ------ | --- |
# 01 |Alice | 1       | 4   | 0    | 2      | 100 | 3
# 02 |Bob   | 4       | 6   | 3    | 2      | 1   | 5
# ...|...   | ...       | ...   | ...    | ...      | ...   | ...

# %% [markdown]
# ## Optimization Using Python and PuLP

# %% [markdown]
# The following subsections walk you through how we used Python to solve the optimization. You can skip this if code isn't your thing :)
#
# Note: This was probably the first code I wrote in Python, so if you are a real user of Python, you will probably notice that this code is not very efficient. Please excuse my lack of expertise in this area!

# %% [markdown]
# ### Read Input Data

# %% [markdown]
# The following Python code reads the csv and prepares the data in the format we will need to use PuLP. The print statements at the end of this section show samples of these inputs.

# %%
#reading files

# raw file
source_csv = 'workshop_survey_clean.csv'
min_class_size = 7

import numpy as np
csv = np.genfromtxt(source_csv, delimiter=",")
csv_rows = len(csv)

preferences = np.zeros((len(csv)-1,6))

# gets preference array
for x in range(1,len(csv)):
    preferences[x-1] =csv[x][2:8]

nstudents=preferences.shape[0]
nworkshops=preferences.shape[1]


rstudents = range(0,nstudents)
rworkshops = range(0,nworkshops)


import csv
with open(source_csv) as csvfile:
    reader = csv.DictReader(csvfile)
    workshop_names = reader.fieldnames[2:8]
    student_names = [row['name'] for row in reader]

print("Number of students: ", nstudents)
print()
print("Number of workshops: ", nworkshops)
print()
print("Minimum workshop size: ", min_class_size)
print()
print("Workshop names: ", workshop_names)
print()
print("Student names (sample): ", student_names[1:5])
print()
print("Preferences matrix (sample): ")
print(preferences[0:3,:])
# Out:
# Number of students:  30
#
# Number of workshops:  6
#
# Minimum workshop size:  7
#
# Workshop names:  ['R Stats', 'Sim', 'APIs', 'Python', 'Viz', 'NLP']
#
# Student names (sample):  ['Outis', 'Odysseus', 'Tiresias', 'Polyphemus']
#
# Preferences matrix (sample):
# [[ 5.  1.  6.  4.  3.  2.]
#  [ 4.  5.  2.  3.  6.  1.]
#  [ 6.  5.  4.  1.  2.  3.]]

# %% [markdown]
# ### Prepare the PuLP Model

# %% [markdown]
# Next, we want to prepare the PuLP model. The following code imports the PuLP package and prepares the objective function and constraints. One thing to note about adding constraints to PuLP is that you need to form the constraints so that all variables are on the left side of the inequality.

# %%
##############################
# prep opt model

import pulp

# Create Problem Instance for Minimization
workshop_model = pulp.LpProblem("Workshop Preferences",pulp.LpMinimize)

# Decision Variable For Workshop Choice By Student
placement = pulp.LpVariable.dicts("Workshop Placement",(rstudents,rworkshops),0,1,pulp.LpInteger)

# Decision Variable For Whether Workshop Offered
offered = pulp.LpVariable.dicts("Workshop Offered",(rworkshops),0,1,pulp.LpInteger)

# Objective = sum(preference*placement)
workshop_model += pulp.lpSum( [[(preferences[student][workshop]) * placement[student][workshop]]
                                     for workshop in rworkshops]
                                     for student in rstudents), "Placement Value"

# A constraint ensuring that only one value can be in each square is created
workshop_model += pulp.lpSum(offered[workshop] for workshop in rworkshops) == 3, "Workshop Sum"

# A constraint ensuring one workshop per student
for student in (rstudents):
    workshop_model += pulp.lpSum(placement[student][workshop] for workshop in rworkshops) == 1, ""

# A constraint ensuring only place in valid workshops
# Note: reformatted to keep variables on left side of inequality
for student in rstudents:
    for workshop in rworkshops:
        workshop_model += placement[student][workshop] - offered[workshop] <= 0,""
        

# A constraint on the minimum number of people per workshop
for workshop in rworkshops:
    workshop_model += pulp.lpSum(placement[student][workshop] for student in rstudents) - min_class_size*offered[workshop] >= 0,""

print(workshop_model)
# Out:
# Workshop Preferences:
# MINIMIZE
# 5.0*Workshop_Placement_0_0 + 1.0*Workshop_Placement_0_1 + 6.0*Workshop_Placement_0_2 + 4.0*Workshop_Placement_0_3 + 3.0*Workshop_Placement_0_4 + 2.0*Workshop_Placement_0_5 + 0.5*Workshop_Placement_10_0 + 4.0*Workshop_Placement_10_1 + 100.0*Workshop_Placement_10_2 + 2.0*Workshop_Placement_10_3 + 100.0*Workshop_Placement_10_4 + 1.0*Workshop_Placement_10_5 + 2.0*Workshop_Placement_11_0 + 4.0*Workshop_Placement_11_1 + 5.0*Workshop_Placement_11_2 + 3.0*Workshop_Placement_11_3 + 1.0*Workshop_Placement_11_4 + 6.0*Workshop_Placement_11_5 + 4.0*Workshop_Placement_12_0 + 3.0*Workshop_Placement_12_1 + 5.0*Workshop_Placement_12_2 + 2.0*Workshop_Placement_12_3 + 1.0*Workshop_Placement_12_4 + 6.0*Workshop_Placement_12_5 + 5.0*Workshop_Placement_13_0 + 1.0*Workshop_Placement_13_1 + 2.0*Workshop_Placement_13_2 + 100.0*Workshop_Placement_13_3 + 4.0*Workshop_Placement_13_4 + 3.0*Workshop_Placement_13_5 + 4.0*Workshop_Placement_14_0 + 5.0*Workshop_Placement_14_1 + 1.0*Workshop_Placement_14_2 + 2.0*Workshop_Placement_14_3 + 6.0*Workshop_Placement_14_4 + 3.0*Workshop_Placement_14_5 + 3.0*Workshop_Placement_15_0 + 2.0*Workshop_Placement_15_1 + 6.0*Workshop_Placement_15_2 + 4.0*Workshop_Placement_15_3 + 1.0*Workshop_Placement_15_4 + 5.0*Workshop_Placement_15_5 + 5.0*Workshop_Placement_16_0 + 6.0*Workshop_Placement_16_1 + 4.0*Workshop_Placement_16_2 + 2.0*Workshop_Placement_16_3 + 3.0*Workshop_Placement_16_4 + 1.0*Workshop_Placement_16_5 + 3.0*Workshop_Placement_17_0 + 1.0*Workshop_Placement_17_1 + 2.0*Workshop_Placement_17_2 + 4.0*Workshop_Placement_17_3 + 5.0*Workshop_Placement_17_4 + 6.0*Workshop_Placement_17_5 + 4.0*Workshop_Placement_18_0 + 1.0*Workshop_Placement_18_1 + 5.0*Workshop_Placement_18_2 + 2.0*Workshop_Placement_18_3 + 3.0*Workshop_Placement_18_5 + 6.0*Workshop_Placement_19_0 + 5.0*Workshop_Placement_19_1 + 4.0*Workshop_Placement_19_2 + 1.0*Workshop_Placement_19_3 + 2.0*Workshop_Placement_19_4 + 3.0*Workshop_Placement_19_5 + 4.0*Workshop_Placement_1_0 + 5.0*Workshop_Placement_1_1 + 2.0*Workshop_Placement_1_2 + 3.0*Workshop_Placement_1_3 + 6.0*Workshop_Placement_1_4 + 1.0*Workshop_Placement_1_5 + 6.0*Workshop_Placement_20_0 + 1.0*Workshop_Placement_20_1 + 4.0*Workshop_Placement_20_2 + 5.0*Workshop_Placement_20_3 + 2.0*Workshop_Placement_20_4 + 3.0*Workshop_Placement_20_5 + 4.0*Workshop_Placement_21_0 + 6.0*Workshop_Placement_21_1 + 3.0*Workshop_Placement_21_2 + 5.0*Workshop_Placement_21_3 + 1.0*Workshop_Placement_21_4 + 2.0*Workshop_Placement_21_5 + 1.0*Workshop_Placement_22_0 + 3.0*Workshop_Placement_22_1 + 2.0*Workshop_Placement_22_2 + 4.0*Workshop_Placement_22_3 + 5.0*Workshop_Placement_22_4 + 6.0*Workshop_Placement_22_5 + 100.0*Workshop_Placement_23_0 + 2.0*Workshop_Placement_23_1 + 1.0*Workshop_Placement_23_2 + 100.0*Workshop_Placement_23_3 + 3.0*Workshop_Placement_23_4 + 100.0*Workshop_Placement_23_5 + 5.0*Workshop_Placement_24_0 + 3.0*Workshop_Placement_24_1 + 6.0*Workshop_Placement_24_2 + 4.0*Workshop_Placement_24_3 + 2.0*Workshop_Placement_24_4 + 1.0*Workshop_Placement_24_5 + 2.0*Workshop_Placement_25_0 + 3.0*Workshop_Placement_25_2 + 5.0*Workshop_Placement_25_3 + 1.0*Workshop_Placement_25_4 + 6.0*Workshop_Placement_25_5 + 6.0*Workshop_Placement_26_0 + 4.0*Workshop_Placement_26_1 + 1.0*Workshop_Placement_26_2 + 5.0*Workshop_Placement_26_3 + 2.0*Workshop_Placement_26_4 + 3.0*Workshop_Placement_26_5 + 100.0*Workshop_Placement_27_0 + 1.0*Workshop_Placement_27_1 + 100.0*Workshop_Placement_27_2 + 100.0*Workshop_Placement_27_3 + 2.0*Workshop_Placement_27_4 + 100.0*Workshop_Placement_27_5 + 100.0*Workshop_Placement_28_0 + 1.0*Workshop_Placement_28_1 + 100.0*Workshop_Placement_28_2 + 100.0*Workshop_Placement_28_3 + 2.0*Workshop_Placement_28_4 + 100.0*Workshop_Placement_28_5 + 1.0*Workshop_Placement_29_0 + 3.0*Workshop_Placement_29_1 + 5.0*Workshop_Placement_29_2 + 4.0*Workshop_Placement_29_3 + 2.0*Workshop_Placement_29_4 + 6.0*Workshop_Placement_29_5 + 6.0*Workshop_Placement_2_0 + 5.0*Workshop_Placement_2_1 + 4.0*Workshop_Placement_2_2 ...
# SUBJECT TO
# Workshop_Sum: Workshop_Offered_0 + Workshop_Offered_1 + Workshop_Offered_2
#  + Workshop_Offered_3 + Workshop_Offered_4 + Workshop_Offered_5 = 3
#
# _C1: Workshop_Placement_0_0 + Workshop_Placement_0_1 + Workshop_Placement_0_2
#  + Workshop_Placement_0_3 + Workshop_Placement_0_4 + Workshop_Placement_0_5
#  = 1
#
# _C2: Workshop_Placement_1_0 + Workshop_Placement_1_1 + Workshop_Placement_1_2
#  + Workshop_Placement_1_3 + Workshop_Placement_1_4 + Workshop_Placement_1_5
#  = 1
#
# _C3: Workshop_Placement_2_0 + Workshop_Placement_2_1 + Workshop_Placement_2_2
#  + Workshop_Placement_2_3 + Workshop_Placement_2_4 + Workshop_Placement_2_5
#  = 1
#
# _C4: Workshop_Placement_3_0 + Workshop_Placement_3_1 + Workshop_Placement_3_2
#  + Workshop_Placement_3_3 + Workshop_Placement_3_4 + Workshop_Placement_3_5
#  = 1
#
# _C5: Workshop_Placement_4_0 + Workshop_Placement_4_1 + Workshop_Placement_4_2
#  + Workshop_Placement_4_3 + Workshop_Placement_4_4 + Workshop_Placement_4_5
#  = 1
#
# _C6: Workshop_Placement_5_0 + Workshop_Placement_5_1 + Workshop_Placement_5_2
#  + Workshop_Placement_5_3 + Workshop_Placement_5_4 + Workshop_Placement_5_5
#  = 1
#
# _C7: Workshop_Placement_6_0 + Workshop_Placement_6_1 + Workshop_Placement_6_2
#  + Workshop_Placement_6_3 + Workshop_Placement_6_4 + Workshop_Placement_6_5
#  = 1
#
# _C8: Workshop_Placement_7_0 + Workshop_Placement_7_1 + Workshop_Placement_7_2
#  + Workshop_Placement_7_3 + Workshop_Placement_7_4 + Workshop_Placement_7_5
#  = 1
#
# _C9: Workshop_Placement_8_0 + Workshop_Placement_8_1 + Workshop_Placement_8_2
#  + Workshop_Placement_8_3 + Workshop_Placement_8_4 + Workshop_Placement_8_5
#  = 1
#
# _C10: Workshop_Placement_9_0 + Workshop_Placement_9_1 + Workshop_Placement_9_2
#  + Workshop_Placement_9_3 + Workshop_Placement_9_4 + Workshop_Placement_9_5
#  = 1
#
# _C11: Workshop_Placement_10_0 + Workshop_Placement_10_1
#  + Workshop_Placement_10_2 + Workshop_Placement_10_3 + Workshop_Placement_10_4
#  + Workshop_Placement_10_5 = 1
#
# _C12: Workshop_Placement_11_0 + Workshop_Placement_11_1
#  + Workshop_Placement_11_2 + Workshop_Placement_11_3 + Workshop_Placement_11_4
#  + Workshop_Placement_11_5 = 1
#
# _C13: Workshop_Placement_12_0 + Workshop_Placement_12_1
#  + Workshop_Placement_12_2 + Workshop_Placement_12_3 + Workshop_Placement_12_4
#  + Workshop_Placement_12_5 = 1
#
# _C14: Workshop_Placement_13_0 + Workshop_Placement_13_1
#  + Workshop_Placement_13_2 + Workshop_Placement_13_3 + Workshop_Placement_13_4
#  + Workshop_Placement_13_5 = 1
#
# _C15: Workshop_Placement_14_0 + Workshop_Placement_14_1
#  + Workshop_Placement_14_2 + Workshop_Placement_14_3 + Workshop_Placement_14_4
#  + Workshop_Placement_14_5 = 1
#
# _C16: Workshop_Placement_15_0 + Workshop_Placement_15_1
#  + Workshop_Placement_15_2 + Workshop_Placement_15_3 + Workshop_Placement_15_4
#  + Workshop_Placement_15_5 = 1
#
# _C17: Workshop_Placement_16_0 + Workshop_Placement_16_1
#  + Workshop_Placement_16_2 + Workshop_Placement_16_3 + Workshop_Placement_16_4
#  + Workshop_Placement_16_5 = 1
#
# _C18: Workshop_Placement_17_0 + Workshop_Placement_17_1
#  + Workshop_Placement_17_2 + Workshop_Placement_17_3 + Workshop_Placement_17_4
#  + Workshop_Placement_17_5 = 1
#
# _C19: Workshop_Placement_18_0 + Workshop_Placement_18_1
#  + Workshop_Placement_18_2 + Workshop_Placement_18_3 + Workshop_Placement_18_4
#  + Workshop_Placement_18_5 = 1
#
# _C20: Workshop_Placement_19_0 + Workshop_Placement_19_1
#  + Workshop_Placement_19_2 + Workshop_Placement_19_3 + Workshop_Placement_19_4
#  + Workshop_Placement_19_5 = 1
#
# _C21: Workshop_Placement_20_0 + Workshop_Placement_20_1
#  + Workshop_Placement_20_2 + Workshop_Placement_20_3 + Workshop_Placement_20_4
#  + Workshop_Placement_20_5 = 1
#
# _C22: Workshop_Placement_21_0 + Workshop_Placement_21_1
#  + Workshop_Placement_21_2 + Workshop_Placement_21_3 + Workshop_Placement_21_4
#  + Workshop_Placement_21_5 = 1
#
# _C23: Workshop_Placement_22_0 + Workshop_Placement_22_1
#  + Workshop_Placement_22_2 + Workshop_Placement_22_3 + Workshop_Placement_22_4
#  + Workshop_Placement_22_5 = 1
#
# _C24: Workshop_Placement_23_0 + Workshop_Placement_23_1
#  + Workshop_Placement_23_2 + Workshop_Placement_23_3 + Workshop_Placement_23_4
#  + Workshop_Placement_23_5 = 1
#
# _C25: Workshop_Placement_24_0 + Workshop_Placement_24_1
#  + Workshop_Placement_24_2 + Workshop_Placement_24_3 + Workshop_Placement_24_4
#  + Workshop_Placement_24_5 = 1
#
# _C26: Workshop_Placement_25_0 + Workshop_Placement_25_1
#  + Workshop_Placement_25_2 + Workshop_Placement_25_3 + Workshop_Placement_25_4
#  + Workshop_Placement_25_5 = 1
#
# _C27: Workshop_Placement_26_0 + Workshop_Placement_26_1
#  + Workshop_Placement_26_2 + Workshop_Placement_26_3 + Workshop_Placement_26_4
#  + Workshop_Placement_26_5 = 1
#
# _C28: Workshop_Placement_27_0 + Workshop_Placement_27_1
#  + Workshop_Placement_27_2 + Workshop_Placement_27_3 + Workshop_Placement_27_4
#  + Workshop_Placement_27_5 = 1
#
# _C29: Workshop_Placement_28_0 + Workshop_Placement_28_1
#  + Workshop_Placement_28_2 + Workshop_Placement_28_3 + Workshop_Placement_28_4
#  + Workshop_Placement_28_5 = 1
#
# _C30: Workshop_Placement_29_0 + Workshop_Placement_29_1
#  + Workshop_Placement_29_2 + Workshop_Placement_29_3 + Workshop_Placement_29_4
#  + Workshop_Placement_29_5 = 1
#
# _C31: - Workshop_Offered_0 + Workshop_Placement_0_0 <= 0
#
# _C32: - Workshop_Offered_1 + Workshop_Placement_0_1 <= 0
#
# _C33: - Workshop_Offered_2 + Workshop_Placement_0_2 <= 0
#
# _C34: - Workshop_Offered_3 + Workshop_Placement_0_3 <= 0
#
# _C35: - Workshop_Offered_4 + Workshop_Placement_0_4 <= 0
#
# _C36: - Workshop_Offered_5 + Workshop_Placement_0_5 <= 0
#
# _C37: - Workshop_Offered_0 + Workshop_Placement_1_0 <= 0
#
# _C38: - Workshop_Offered_1 + Workshop_Placement_1_1 <= 0
#
# _C39: - Workshop_Offered_2 + Workshop_Placement_1_2 <= 0
#
# _C40: - Workshop_Offered_3 + Workshop_Placement_1_3 <= 0
#
# _C41: - Workshop_Offered_4 + Workshop_Placement_1_4 <= 0
#
# _C42: - Workshop_Offered_5 + Workshop_Placement_1_5 <= 0
#
# _C43: - Workshop_Offered_0 + Workshop_Placement_2_0 <= 0
#
# _C44: - Workshop_Offered_1 + Workshop_Placement_2_1 <= 0
#
# _C45: - Workshop_Offered_2 + Workshop_Placement_2_2 <= 0
#
# _C46: - Workshop_Offered_3 + Workshop_Placement_2_3 <= 0
#
# _C47: - Workshop_Offered_4 + Workshop_Placement_2_4 <= 0
#
# _C48: - Workshop_Offered_5 + Workshop_Placement_2_5 <= 0
#
# _C49: - Workshop_Offered_0 + Workshop_Placement_3_0 <= 0
#
# _C50: - Workshop_Offered_1 + Workshop_Placement_3_1 <= 0
#
# _C51: - Workshop_Offered_2 + Workshop_Placement_3_2 <= 0
#
# _C52: - Workshop_Offered_3 + Workshop_Placement_3_3 <= 0
#
# _C53: - Workshop_Offered_4 + Workshop_Placement_3_4 <= 0
#
# _C54: - Workshop_Offered_5 + Workshop_Placement_3_5 <= 0
#
# _C55: - Workshop_Offered_0 + Workshop_Placement_4_0 <= 0
#
# _C56: - Workshop_Offered_1 + Workshop_Placement_4_1 <= 0
#
# _C57: - Workshop_Offered_2 + Workshop_Placement_4_2 <= 0
#
# _C58: - Workshop_Offered_3 + Workshop_Placement_4_3 <= 0
#
# _C59: - Workshop_Offered_4 + Workshop_Placement_4_4 <= 0
#
# _C60: - Workshop_Offered_5 + Workshop_Placement_4_5 <= 0
#
# _C61: - Workshop_Offered_0 + Workshop_Placement_5_0 <= 0
#
# _C62: - Workshop_Offered_1 + Workshop_Placement_5_1 <= 0
#
# _C63: - Workshop_Offered_2 + Workshop_Placement_5_2 <= 0
#
# _C64: - Workshop_Offered_3 + Workshop_Placement_5_3 <= 0
#
# _C65: - Workshop_Offered_4 + Workshop_Placement_5_4 <= 0
#
# _C66: - Workshop_Offered_5 + Workshop_Placement_5_5 <= 0
#
# _C67: - Workshop_Offered_0 + Workshop_Placement_6_0 <= 0
#
# _C68: - Workshop_Offered_1 + Workshop_Placement_6_1 <= 0
#
# _C69: - Workshop_Offered_2 + Workshop_Placement_6_2 <= 0
#
# _C70: - Workshop_Offered_3 + Workshop_Placement_6_3 <= 0
#
# _C71: - Workshop_Offered_4 + Workshop_Placement_6_4 <= 0
#
# _C72: - Workshop_Offered_5 + Workshop_Placement_6_5 <= 0
#
# _C73: - Workshop_Offered_0 + Workshop_Placement_7_0 <= 0
#
# _C74: - Workshop_Offered_1 + Workshop_Placement_7_1 <= 0
#
# _C75: - Workshop_Offered_2 + Workshop_Placement_7_2 <= 0
#
# _C76: - Workshop_Offered_3 + Workshop_Placement_7_3 <= 0
#
# _C77: - Workshop_Offered_4 + Workshop_Placement_7_4 <= 0
#
# _C78: - Workshop_Offered_5 + Workshop_Placement_7_5 <= 0
#
# _C79: - Workshop_Offered_0 + Workshop_Placement_8_0 <= 0
#
# _C80: - Workshop_Offered_1 + Workshop_Placement_8_1 <= 0
#
# _C81: - Workshop_Offered_2 + Workshop_Placement_8_2 <= 0
#
# _C82: - Workshop_Offered_3 + Workshop_Placement_8_3 <= 0
#
# _C83: - Workshop_Offered_4 + Workshop_Placement_8_4 <= 0
#
# _C84: - Workshop_Offered_5 + Workshop_Placement_8_5 <= 0
#
# _C85: - Workshop_Offered_0 + Workshop_Placement_9_0 <= 0
#
# _C86: - Workshop_Offered_1 + Workshop_Placement_9_1 <= 0
#
# _C87: - Workshop_Offered_2 + Workshop_Placement_9_2 <= 0
#
# _C88: - Workshop_Offered_3 + Workshop_Placement_9_3 <= 0
#
# _C89: - Workshop_Offered_4 + Workshop_Placement_9_4 <= 0
#
# _C90: - Workshop_Offered_5 + Workshop_Placement_9_5 <= 0
#
# _C91: - Workshop_Offered_0 + Workshop_Placement_10_0 <= 0
#
# _C92: - Workshop_Offered_1 + Workshop_Placement_10_1 <= 0
#
# _C93: - Workshop_Offered_2 + Workshop_Placement_10_2 <= 0
#
# _C94: - Workshop_Offered_3 + Workshop_Placement_10_3 <= 0
#
# _C95: - Workshop_Offered_4 + Workshop_Placement_10_4 <= 0
#
# _C96: - Workshop_Offered_5 + Workshop_Placement_10_5 <= 0
#
# _C97: - Workshop_Offered_0 + Workshop_Placement_11_0 <= 0
#
# _C98: - Workshop_Offered_1 + Workshop_Placement_11_1 <= 0
#
# _C99: - Workshop_Offered_2 + Workshop_Placement_11_2 <= 0
#
# _C100: - Workshop_Offered_3 + Workshop_Placement_11_3 <= 0
#
# _C101: - Workshop_Offered_4 + Workshop_Placement_11_4 <= 0
#
# _C102: - Workshop_Offered_5 + Workshop_Placement_11_5 <= 0
#
# _C103: - Workshop_Offered_0 + Workshop_Placement_12_0 <= 0
#
# _C104: - Workshop_Offered_1 + Workshop_Placement_12_1 <= 0
#
# _C105: - Workshop_Offered_2 + Workshop_Placement_12_2 <= 0
#
# _C106: - Workshop_Offered_3 + Workshop_Placement_12_3 <= 0
#
# _C107: - Workshop_Offered_4 + Workshop_Placement_12_4 <= 0
#
# _C108: - Workshop_Offered_5 + Workshop_Placement_12_5 <= 0
#
# _C109: - Workshop_Offered_0 + Workshop_Placement_13_0 <= 0
#
# _C110: - Workshop_Offered_1 + Workshop_Placement_13_1 <= 0
#
# _C111: - Workshop_Offered_2 + Workshop_Placement_13_2 <= 0
#
# _C112: - Workshop_Offered_3 + Workshop_Placement_13_3 <= 0
#
# _C113: - Workshop_Offered_4 + Workshop_Placement_13_4 <= 0
#
# _C114: - Workshop_Offered_5 + Workshop_Placement_13_5 <= 0
#
# _C115: - Workshop_Offered_0 + Workshop_Placement_14_0 <= 0
#
# _C116: - Workshop_Offered_1 + Workshop_Placement_14_1 <= 0
#
# _C117: - Workshop_Offered_2 + Workshop_Placement_14_2 <= 0
#
# _C118: - Workshop_Offered_3 + Workshop_Placement_14_3 <= 0
#
# _C119: - Workshop_Offered_4 + Workshop_Placement_14_4 <= 0
#
# _C120: - Workshop_Offered_5 + Workshop_Placement_14_5 <= 0
#
# _C121: - Workshop_Offered_0 + Workshop_Placement_15_0 <= 0
#
# _C122: - Workshop_Offered_1 + Workshop_Placement_15_1 <= 0
#
# _C123: - Workshop_Offered_2 + Workshop_Placement_15_2 <= 0
#
# _C124: - Workshop_Offered_3 + Workshop_Placement_15_3 <= 0
#
# _C125: - Workshop_Offered_4 + Workshop_Placement_15_4 <= 0
#
# _C126: - Workshop_Offered_5 + Workshop_Placement_15_5 <= 0
#
# _C127: - Workshop_Offered_0 + Workshop_Placement_16_0 <= 0
#
# _C128: - Workshop_Offered_1 + Workshop_Placement_16_1 <= 0
#
# _C129: - Workshop_Offered_2 + Workshop_Placement_16_2 <= 0
#
# _C130: - Workshop_Offered_3 + Workshop_Placement_16_3 <= 0
#
# _C131: - Workshop_Offered_4 + Workshop_Placement_16_4 <= 0
#
# _C132: - Workshop_Offered_5 + Workshop_Placement_16_5 <= 0
#
# _C133: - Workshop_Offered_0 + Workshop_Placement_17_0 <= 0
#
# _C134: - Workshop_Offered_1 + Workshop_Placement_17_1 <= 0
#
# _C135: - Workshop_Offered_2 + Workshop_Placement_17_2 <= 0
#
# _C136: - Workshop_Offered_3 + Workshop_Placement_17_3 <= 0
#
# _C137: - Workshop_Offered_4 + Workshop_Placement_17_4 <= 0
#
# _C138: - Workshop_Offered_5 + Workshop_Placement_17_5 <= 0
#
# _C139: - Workshop_Offered_0 + Workshop_Placement_18_0 <= 0
#
# _C140: - Workshop_Offered_1 + Workshop_Placement_18_1 <= 0
#
# _C141: - Workshop_Offered_2 + Workshop_Placement_18_2 <= 0
#
# _C142: - Workshop_Offered_3 + Workshop_Placement_18_3 <= 0
#
# _C143: - Workshop_Offered_4 + Workshop_Placement_18_4 <= 0
#
# _C144: - Workshop_Offered_5 + Workshop_Placement_18_5 <= 0
#
# _C145: - Workshop_Offered_0 + Workshop_Placement_19_0 <= 0
#
# _C146: - Workshop_Offered_1 + Workshop_Placement_19_1 <= 0
#
# _C147: - Workshop_Offered_2 + Workshop_Placement_19_2 <= 0
#
# _C148: - Workshop_Offered_3 + Workshop_Placement_19_3 <= 0
#
# _C149: - Workshop_Offered_4 + Workshop_Placement_19_4 <= 0
#
# _C150: - Workshop_Offered_5 + Workshop_Placement_19_5 <= 0
#
# _C151: - Workshop_Offered_0 + Workshop_Placement_20_0 <= 0
#
# _C152: - Workshop_Offered_1 + Workshop_Placement_20_1 <= 0
#
# _C153: - Workshop_Offered_2 + Workshop_Placement_20_2 <= 0
#
# _C154: - Workshop_Offered_3 + Workshop_Placement_20_3 <= 0
#
# _C155: - Workshop_Offered_4 + Workshop_Placement_20_4 <= 0
#
# _C156: - Workshop_Offered_5 + Workshop_Placement_20_5 <= 0
#
# _C157: - Workshop_Offered_0 + Workshop_Placement_21_0 <= 0
#
# _C158: - Workshop_Offered_1 + Workshop_Placement_21_1 <= 0
#
# _C159: - Workshop_Offered_2 + Workshop_Placement_21_2 <= 0
#
# _C160: - Workshop_Offered_3 + Workshop_Placement_21_3 <= 0
#
# _C161: - Workshop_Offered_4 + Workshop_Placement_21_4 <= 0
#
# _C162: - Workshop_Offered_5 + Workshop_Placement_21_5 <= 0
#
# _C163: - Workshop_Offered_0 + Workshop_Placement_22_0 <= 0
#
# _C164: - Workshop_Offered_1 + Workshop_Placement_22_1 <= 0
#
# _C165: - Workshop_Offered_2 + Workshop_Placement_22_2 <= 0
#
# _C166: - Workshop_Offered_3 + Workshop_Placement_22_3 <= 0
#
# _C167: - Workshop_Offered_4 + Workshop_Placement_22_4 <= 0
#
# _C168: - Workshop_Offered_5 + Workshop_Placement_22_5 <= 0
#
# _C169: - Workshop_Offered_0 + Workshop_Placement_23_0 <= 0
#
# _C170: - Workshop_Offered_1 + Workshop_Placement_23_1 <= 0
#
# _C171: - Workshop_Offered_2 + Workshop_Placement_23_2 <= 0
#
# _C172: - Workshop_Offered_3 + Workshop_Placement_23_3 <= 0
#
# _C173: - Workshop_Offered_4 + Workshop_Placement_23_4 <= 0
#
# _C174: - Workshop_Offered_5 + Workshop_Placement_23_5 <= 0
#
# _C175: - Workshop_Offered_0 + Workshop_Placement_24_0 <= 0
#
# _C176: - Workshop_Offered_1 + Workshop_Placement_24_1 <= 0
#
# _C177: - Workshop_Offered_2 + Workshop_Placement_24_2 <= 0
#
# _C178: - Workshop_Offered_3 + Workshop_Placement_24_3 <= 0
#
# _C179: - Workshop_Offered_4 + Workshop_Placement_24_4 <= 0
#
# _C180: - Workshop_Offered_5 + Workshop_Placement_24_5 <= 0
#
# _C181: - Workshop_Offered_0 + Workshop_Placement_25_0 <= 0
#
# _C182: - Workshop_Offered_1 + Workshop_Placement_25_1 <= 0
#
# _C183: - Workshop_Offered_2 + Workshop_Placement_25_2 <= 0
#
# _C184: - Workshop_Offered_3 + Workshop_Placement_25_3 <= 0
#
# _C185: - Workshop_Offered_4 + Workshop_Placement_25_4 <= 0
#
# _C186: - Workshop_Offered_5 + Workshop_Placement_25_5 <= 0
#
# _C187: - Workshop_Offered_0 + Workshop_Placement_26_0 <= 0
#
# _C188: - Workshop_Offered_1 + Workshop_Placement_26_1 <= 0
#
# _C189: - Workshop_Offered_2 + Workshop_Placement_26_2 <= 0
#
# _C190: - Workshop_Offered_3 + Workshop_Placement_26_3 <= 0
#
# _C191: - Workshop_Offered_4 + Workshop_Placement_26_4 <= 0
#
# _C192: - Workshop_Offered_5 + Workshop_Placement_26_5 <= 0
#
# _C193: - Workshop_Offered_0 + Workshop_Placement_27_0 <= 0
#
# _C194: - Workshop_Offered_1 + Workshop_Placement_27_1 <= 0
#
# _C195: - Workshop_Offered_2 + Workshop_Placement_27_2 <= 0
#
# _C196: - Workshop_Offered_3 + Workshop_Placement_27_3 <= 0
#
# _C197: - Workshop_Offered_4 + Workshop_Placement_27_4 <= 0
#
# _C198: - Workshop_Offered_5 + Workshop_Placement_27_5 <= 0
#
# _C199: - Workshop_Offered_0 + Workshop_Placement_28_0 <= 0
#
# _C200: - Workshop_Offered_1 + Workshop_Placement_28_1 <= 0
#
# _C201: - Workshop_Offered_2 + Workshop_Placement_28_2 <= 0
#
# _C202: - Workshop_Offered_3 + Workshop_Placement_28_3 <= 0
#
# _C203: - Workshop_Offered_4 + Workshop_Placement_28_4 <= 0
#
# _C204: - Workshop_Offered_5 + Workshop_Placement_28_5 <= 0
#
# _C205: - Workshop_Offered_0 + Workshop_Placement_29_0 <= 0
#
# _C206: - Workshop_Offered_1 + Workshop_Placement_29_1 <= 0
#
# _C207: - Workshop_Offered_2 + Workshop_Placement_29_2 <= 0
#
# _C208: - Workshop_Offered_3 + Workshop_Placement_29_3 <= 0
#
# _C209: - Workshop_Offered_4 + Workshop_Placement_29_4 <= 0
#
# _C210: - Workshop_Offered_5 + Workshop_Placement_29_5 <= 0
#
# _C211: - 7 Workshop_Offered_0 + Workshop_Placement_0_0
#  + Workshop_Placement_10_0 + Workshop_Placement_11_0 + Workshop_Placement_12_0
#  + Workshop_Placement_13_0 + Workshop_Placement_14_0 + Workshop_Placement_15_0
#  + Workshop_Placement_16_0 + Workshop_Placement_17_0 + Workshop_Placement_18_0
#  + Workshop_Placement_19_0 + Workshop_Placement_1_0 + Workshop_Placement_20_0
#  + Workshop_Placement_21_0 + Workshop_Placement_22_0 + Workshop_Placement_23_0
#  + Workshop_Placement_24_0 + Workshop_Placement_25_0 + Workshop_Placement_26_0
#  + Workshop_Placement_27_0 + Workshop_Placement_28_0 + Workshop_Placement_29_0
#  + Workshop_Placement_2_0 + Workshop_Placement_3_0 + Workshop_Placement_4_0
#  + Workshop_Placement_5_0 + Workshop_Placement_6_0 + Workshop_Placement_7_0
#  + Workshop_Placement_8_0 + Workshop_Placement_9_0 >= 0
#
# _C212: - 7 Workshop_Offered_1 + Workshop_Placement_0_1
#  + Workshop_Placement_10_1 + Workshop_Placement_11_1 + Workshop_Placement_12_1
#  + Workshop_Placement_13_1 + Workshop_Placement_14_1 + Workshop_Placement_15_1
#  + Workshop_Placement_16_1 + Workshop_Placement_17_1 + Workshop_Placement_18_1
#  + Workshop_Placement_19_1 + Workshop_Placement_1_1 + Workshop_Placement_20_1
#  + Workshop_Placement_21_1 + Workshop_Placement_22_1 + Workshop_Placement_23_1
#  + Workshop_Placement_24_1 + Workshop_Placement_25_1 + Workshop_Placement_26_1
#  + Workshop_Placement_27_1 + Workshop_Placement_28_1 + Workshop_Placement_29_1
#  + Workshop_Placement_2_1 + Workshop_Placement_3_1 + Workshop_Placement_4_1
#  + Workshop_Placement_5_1 + Workshop_Placement_6_1 + Workshop_Placement_7_1
#  + Workshop_Placement_8_1 + Workshop_Placement_9_1 >= 0
#
# _C213: - 7 Workshop_Offered_2 + Workshop_Placement_0_2
#  + Workshop_Placement_10_2 + Workshop_Placement_11_2 + Workshop_Placement_12_2
#  + Workshop_Placement_13_2 + Workshop_Placement_14_2 + Workshop_Placement_15_2
#  + Workshop_Placement_16_2 + Workshop_Placement_17_2 + Workshop_Placement_18_2
#  + Workshop_Placement_19_2 + Workshop_Placement_1_2 + Workshop_Placement_20_2
#  + Workshop_Placement_21_2 + Workshop_Placement_22_2 + Workshop_Placement_23_2
#  + Workshop_Placement_24_2 + Workshop_Placement_25_2 + Workshop_Placement_26_2
#  + Workshop_Placement_27_2 + Workshop_Placement_28_2 + Workshop_Placement_29_2
#  + Workshop_Placement_2_2 + Workshop_Placement_3_2 + Workshop_Placement_4_2
#  + Workshop_Placement_5_2 + Workshop_Placement_6_2 + Workshop_Placement_7_2
#  + Workshop_Placement_8_2 + Workshop_Placement_9_2 >= 0
#
# _C214: - 7 Workshop_Offered_3 + Workshop_Placement_0_3
#  + Workshop_Placement_10_3 + Workshop_Placement_11_3 + Workshop_Placement_12_3
#  + Workshop_Placement_13_3 + Workshop_Placement_14_3 + Workshop_Placement_15_3
#  + Workshop_Placement_16_3 + Workshop_Placement_17_3 + Workshop_Placement_18_3
#  + Workshop_Placement_19_3 + Workshop_Placement_1_3 + Workshop_Placement_20_3
#  + Workshop_Placement_21_3 + Workshop_Placement_22_3 + Workshop_Placement_23_3
#  + Workshop_Placement_24_3 + Workshop_Placement_25_3 + Workshop_Placement_26_3
#  + Workshop_Placement_27_3 + Workshop_Placement_28_3 + Workshop_Placement_29_3
#  + Workshop_Placement_2_3 + Workshop_Placement_3_3 + Workshop_Placement_4_3
#  + Workshop_Placement_5_3 + Workshop_Placement_6_3 + Workshop_Placement_7_3
#  + Workshop_Placement_8_3 + Workshop_Placement_9_3 >= 0
#
# _C215: - 7 Workshop_Offered_4 + Workshop_Placement_0_4
#  + Workshop_Placement_10_4 + Workshop_Placement_11_4 + Workshop_Placement_12_4
#  + Workshop_Placement_13_4 + Workshop_Placement_14_4 + Workshop_Placement_15_4
#  + Workshop_Placement_16_4 + Workshop_Placement_17_4 + Workshop_Placement_18_4
#  + Workshop_Placement_19_4 + Workshop_Placement_1_4 + Workshop_Placement_20_4
#  + Workshop_Placement_21_4 + Workshop_Placement_22_4 + Workshop_Placement_23_4
#  + Workshop_Placement_24_4 + Workshop_Placement_25_4 + Workshop_Placement_26_4
#  + Workshop_Placement_27_4 + Workshop_Placement_28_4 + Workshop_Placement_29_4
#  + Workshop_Placement_2_4 + Workshop_Placement_3_4 + Workshop_Placement_4_4
#  + Workshop_Placement_5_4 + Workshop_Placement_6_4 + Workshop_Placement_7_4
#  + Workshop_Placement_8_4 + Workshop_Placement_9_4 >= 0
#
# _C216: - 7 Workshop_Offered_5 + Workshop_Placement_0_5
#  + Workshop_Placement_10_5 + Workshop_Placement_11_5 + Workshop_Placement_12_5
#  + Workshop_Placement_13_5 + Workshop_Placement_14_5 + Workshop_Placement_15_5
#  + Workshop_Placement_16_5 + Workshop_Placement_17_5 + Workshop_Placement_18_5
#  + Workshop_Placement_19_5 + Workshop_Placement_1_5 + Workshop_Placement_20_5
#  + Workshop_Placement_21_5 + Workshop_Placement_22_5 + Workshop_Placement_23_5
#  + Workshop_Placement_24_5 + Workshop_Placement_25_5 + Workshop_Placement_26_5
#  + Workshop_Placement_27_5 + Workshop_Placement_28_5 + Workshop_Placement_29_5
#  + Workshop_Placement_2_5 + Workshop_Placement_3_5 + Workshop_Placement_4_5
#  + Workshop_Placement_5_5 + Workshop_Placement_6_5 + Workshop_Placement_7_5
#  + Workshop_Placement_8_5 + Workshop_Placement_9_5 >= 0
#
# VARIABLES
# 0 <= Workshop_Offered_0 <= 1 Integer
# 0 <= Workshop_Offered_1 <= 1 Integer
# 0 <= Workshop_Offered_2 <= 1 Integer
# 0 <= Workshop_Offered_3 <= 1 Integer
# 0 <= Workshop_Offered_4 <= 1 Integer
# 0 <= Workshop_Offered_5 <= 1 Integer
# 0 <= Workshop_Placement_0_0 <= 1 Integer
# 0 <= Workshop_Placement_0_1 <= 1 Integer
# 0 <= Workshop_Placement_0_2 <= 1 Integer
# 0 <= Workshop_Placement_0_3 <= 1 Integer
# 0 <= Workshop_Placement_0_4 <= 1 Integer
# 0 <= Workshop_Placement_0_5 <= 1 Integer
# 0 <= Workshop_Placement_10_0 <= 1 Integer
# 0 <= Workshop_Placement_10_1 <= 1 Integer
# 0 <= Workshop_Placement_10_2 <= 1 Integer
# 0 <= Workshop_Placement_10_3 <= 1 Integer
# 0 <= Workshop_Placement_10_4 <= 1 Integer
# 0 <= Workshop_Placement_10_5 <= 1 Integer
# 0 <= Workshop_Placement_11_0 <= 1 Integer
# 0 <= Workshop_Placement_11_1 <= 1 Integer
# 0 <= Workshop_Placement_11_2 <= 1 Integer
# 0 <= Workshop_Placement_11_3 <= 1 Integer
# 0 <= Workshop_Placement_11_4 <= 1 Integer
# 0 <= Workshop_Placement_11_5 <= 1 Integer
# 0 <= Workshop_Placement_12_0 <= 1 Integer
# 0 <= Workshop_Placement_12_1 <= 1 Integer
# 0 <= Workshop_Placement_12_2 <= 1 Integer
# 0 <= Workshop_Placement_12_3 <= 1 Integer
# 0 <= Workshop_Placement_12_4 <= 1 Integer
# 0 <= Workshop_Placement_12_5 <= 1 Integer
# 0 <= Workshop_Placement_13_0 <= 1 Integer
# 0 <= Workshop_Placement_13_1 <= 1 Integer
# 0 <= Workshop_Placement_13_2 <= 1 Integer
# 0 <= Workshop_Placement_13_3 <= 1 Integer
# 0 <= Workshop_Placement_13_4 <= 1 Integer
# 0 <= Workshop_Placement_13_5 <= 1 Integer
# 0 <= Workshop_Placement_14_0 <= 1 Integer
# 0 <= Workshop_Placement_14_1 <= 1 Integer
# 0 <= Workshop_Placement_14_2 <= 1 Integer
# 0 <= Workshop_Placement_14_3 <= 1 Integer
# 0 <= Workshop_Placement_14_4 <= 1 Integer
# 0 <= Workshop_Placement_14_5 <= 1 Integer
# 0 <= Workshop_Placement_15_0 <= 1 Integer
# 0 <= Workshop_Placement_15_1 <= 1 Integer
# 0 <= Workshop_Placement_15_2 <= 1 Integer
# 0 <= Workshop_Placement_15_3 <= 1 Integer
# 0 <= Workshop_Placement_15_4 <= 1 Integer
# 0 <= Workshop_Placement_15_5 <= 1 Integer
# 0 <= Workshop_Placement_16_0 <= 1 Integer
# 0 <= Workshop_Placement_16_1 <= 1 Integer
# 0 <= Workshop_Placement_16_2 <= 1 Integer
# 0 <= Workshop_Placement_16_3 <= 1 Integer
# 0 <= Workshop_Placement_16_4 <= 1 Integer
# 0 <= Workshop_Placement_16_5 <= 1 Integer
# 0 <= Workshop_Placement_17_0 <= 1 Integer
# 0 <= Workshop_Placement_17_1 <= 1 Integer
# 0 <= Workshop_Placement_17_2 <= 1 Integer
# 0 <= Workshop_Placement_17_3 <= 1 Integer
# 0 <= Workshop_Placement_17_4 <= 1 Integer
# 0 <= Workshop_Placement_17_5 <= 1 Integer
# 0 <= Workshop_Placement_18_0 <= 1 Integer
# 0 <= Workshop_Placement_18_1 <= 1 Integer
# 0 <= Workshop_Placement_18_2 <= 1 Integer
# 0 <= Workshop_Placement_18_3 <= 1 Integer
# 0 <= Workshop_Placement_18_4 <= 1 Integer
# 0 <= Workshop_Placement_18_5 <= 1 Integer
# 0 <= Workshop_Placement_19_0 <= 1 Integer
# 0 <= Workshop_Placement_19_1 <= 1 Integer
# 0 <= Workshop_Placement_19_2 <= 1 Integer
# 0 <= Workshop_Placement_19_3 <= 1 Integer
# 0 <= Workshop_Placement_19_4 <= 1 Integer
# 0 <= Workshop_Placement_19_5 <= 1 Integer
# 0 <= Workshop_Placement_1_0 <= 1 Integer
# 0 <= Workshop_Placement_1_1 <= 1 Integer
# 0 <= Workshop_Placement_1_2 <= 1 Integer
# 0 <= Workshop_Placement_1_3 <= 1 Integer
# 0 <= Workshop_Placement_1_4 <= 1 Integer
# 0 <= Workshop_Placement_1_5 <= 1 Integer
# 0 <= Workshop_Placement_20_0 <= 1 Integer
# 0 <= Workshop_Placement_20_1 <= 1 Integer
# 0 <= Workshop_Placement_20_2 <= 1 Integer
# 0 <= Workshop_Placement_20_3 <= 1 Integer
# 0 <= Workshop_Placement_20_4 <= 1 Integer
# 0 <= Workshop_Placement_20_5 <= 1 Integer
# 0 <= Workshop_Placement_21_0 <= 1 Integer
# 0 <= Workshop_Placement_21_1 <= 1 Integer
# 0 <= Workshop_Placement_21_2 <= 1 Integer
# 0 <= Workshop_Placement_21_3 <= 1 Integer
# 0 <= Workshop_Placement_21_4 <= 1 Integer
# 0 <= Workshop_Placement_21_5 <= 1 Integer
# 0 <= Workshop_Placement_22_0 <= 1 Integer
# 0 <= Workshop_Placement_22_1 <= 1 Integer
# 0 <= Workshop_Placement_22_2 <= 1 Integer
# 0 <= Workshop_Placement_22_3 <= 1 Integer
# 0 <= Workshop_Placement_22_4 <= 1 Integer
# 0 <= Workshop_Placement_22_5 <= 1 Integer
# 0 <= Workshop_Placement_23_0 <= 1 Integer
# 0 <= Workshop_Placement_23_1 <= 1 Integer
# 0 <= Workshop_Placement_23_2 <= 1 Integer
# 0 <= Workshop_Placement_23_3 <= 1 Integer
# 0 <= Workshop_Placement_23_4 <= 1 Integer
# 0 <= Workshop_Placement_23_5 <= 1 Integer
# 0 <= Workshop_Placement_24_0 <= 1 Integer
# 0 <= Workshop_Placement_24_1 <= 1 Integer
# 0 <= Workshop_Placement_24_2 <= 1 Integer
# 0 <= Workshop_Placement_24_3 <= 1 Integer
# 0 <= Workshop_Placement_24_4 <= 1 Integer
# 0 <= Workshop_Placement_24_5 <= 1 Integer
# 0 <= Workshop_Placement_25_0 <= 1 Integer
# 0 <= Workshop_Placement_25_1 <= 1 Integer
# 0 <= Workshop_Placement_25_2 <= 1 Integer
# 0 <= Workshop_Placement_25_3 <= 1 Integer
# 0 <= Workshop_Placement_25_4 <= 1 Integer
# 0 <= Workshop_Placement_25_5 <= 1 Integer
# 0 <= Workshop_Placement_26_0 <= 1 Integer
# 0 <= Workshop_Placement_26_1 <= 1 Integer
# 0 <= Workshop_Placement_26_2 <= 1 Integer
# 0 <= Workshop_Placement_26_3 <= 1 Integer
# 0 <= Workshop_Placement_26_4 <= 1 Integer
# 0 <= Workshop_Placement_26_5 <= 1 Integer
# 0 <= Workshop_Placement_27_0 <= 1 Integer
# 0 <= Workshop_Placement_27_1 <= 1 Integer
# 0 <= Workshop_Placement_27_2 <= 1 Integer
# 0 <= Workshop_Placement_27_3 <= 1 Integer
# 0 <= Workshop_Placement_27_4 <= 1 Integer
# 0 <= Workshop_Placement_27_5 <= 1 Integer
# 0 <= Workshop_Placement_28_0 <= 1 Integer
# 0 <= Workshop_Placement_28_1 <= 1 Integer
# 0 <= Workshop_Placement_28_2 <= 1 Integer
# 0 <= Workshop_Placement_28_3 <= 1 Integer
# 0 <= Workshop_Placement_28_4 <= 1 Integer
# 0 <= Workshop_Placement_28_5 <= 1 Integer
# 0 <= Workshop_Placement_29_0 <= 1 Integer
# 0 <= Workshop_Placement_29_1 <= 1 Integer
# 0 <= Workshop_Placement_29_2 <= 1 Integer
# 0 <= Workshop_Placement_29_3 <= 1 Integer
# 0 <= Workshop_Placement_29_4 <= 1 Integer
# 0 <= Workshop_Placement_29_5 <= 1 Integer
# 0 <= Workshop_Placement_2_0 <= 1 Integer
# 0 <= Workshop_Placement_2_1 <= 1 Integer
# 0 <= Workshop_Placement_2_2 <= 1 Integer
# 0 <= Workshop_Placement_2_3 <= 1 Integer
# 0 <= Workshop_Placement_2_4 <= 1 Integer
# 0 <= Workshop_Placement_2_5 <= 1 Integer
# 0 <= Workshop_Placement_3_0 <= 1 Integer
# 0 <= Workshop_Placement_3_1 <= 1 Integer
# 0 <= Workshop_Placement_3_2 <= 1 Integer
# 0 <= Workshop_Placement_3_3 <= 1 Integer
# 0 <= Workshop_Placement_3_4 <= 1 Integer
# 0 <= Workshop_Placement_3_5 <= 1 Integer
# 0 <= Workshop_Placement_4_0 <= 1 Integer
# 0 <= Workshop_Placement_4_1 <= 1 Integer
# 0 <= Workshop_Placement_4_2 <= 1 Integer
# 0 <= Workshop_Placement_4_3 <= 1 Integer
# 0 <= Workshop_Placement_4_4 <= 1 Integer
# 0 <= Workshop_Placement_4_5 <= 1 Integer
# 0 <= Workshop_Placement_5_0 <= 1 Integer
# 0 <= Workshop_Placement_5_1 <= 1 Integer
# 0 <= Workshop_Placement_5_2 <= 1 Integer
# 0 <= Workshop_Placement_5_3 <= 1 Integer
# 0 <= Workshop_Placement_5_4 <= 1 Integer
# 0 <= Workshop_Placement_5_5 <= 1 Integer
# 0 <= Workshop_Placement_6_0 <= 1 Integer
# 0 <= Workshop_Placement_6_1 <= 1 Integer
# 0 <= Workshop_Placement_6_2 <= 1 Integer
# 0 <= Workshop_Placement_6_3 <= 1 Integer
# 0 <= Workshop_Placement_6_4 <= 1 Integer
# 0 <= Workshop_Placement_6_5 <= 1 Integer
# 0 <= Workshop_Placement_7_0 <= 1 Integer
# 0 <= Workshop_Placement_7_1 <= 1 Integer
# 0 <= Workshop_Placement_7_2 <= 1 Integer
# 0 <= Workshop_Placement_7_3 <= 1 Integer
# 0 <= Workshop_Placement_7_4 <= 1 Integer
# 0 <= Workshop_Placement_7_5 <= 1 Integer
# 0 <= Workshop_Placement_8_0 <= 1 Integer
# 0 <= Workshop_Placement_8_1 <= 1 Integer
# 0 <= Workshop_Placement_8_2 <= 1 Integer
# 0 <= Workshop_Placement_8_3 <= 1 Integer
# 0 <= Workshop_Placement_8_4 <= 1 Integer
# 0 <= Workshop_Placement_8_5 <= 1 Integer
# 0 <= Workshop_Placement_9_0 <= 1 Integer
# 0 <= Workshop_Placement_9_1 <= 1 Integer
# 0 <= Workshop_Placement_9_2 <= 1 Integer
# 0 <= Workshop_Placement_9_3 <= 1 Integer
# 0 <= Workshop_Placement_9_4 <= 1 Integer
# 0 <= Workshop_Placement_9_5 <= 1 Integer

# %% [markdown]
# But wait! What is this print out mess we have? At the end of the model creation, I asked Python to print the entire model we had constructed. This means it has printed out the objective ("MINIMIZE ... " up to "SUBJECT TO") and the constraints (after "SUBJECT TO"). The reason there are so many more things printed here than when we formulated the model is that PuLP has expanded the simple formulation we gave it to the detail level. For example, our formulation of the one-workshop-per-student constraint:
#
# $$
#     \sum\limits_{workshops} x_{student,workshop} = 1 \ \ \forall \ \ students \\
# $$
#
# turns into one constraint per student in the PuLP formulation, and the sum is expanded to explicitly state each workshop for the given student, as follows:
# ```
# _C1: Workshop_Placement_0_0 + Workshop_Placement_0_1 + Workshop_Placement_0_2
#  + Workshop_Placement_0_3 + Workshop_Placement_0_4 + Workshop_Placement_0_5
#  = 1
#
# _C2: Workshop_Placement_1_0 + Workshop_Placement_1_1 + Workshop_Placement_1_2
#  + Workshop_Placement_1_3 + Workshop_Placement_1_4 + Workshop_Placement_1_5
#  = 1
#
#  ...
#  ```

# %% [markdown]
# ### Solving the PuLP Model

# %% [markdown]
# Now that the model is formulated, we simple submit a request to solve it. The status shows that the PuLP solver was able to find an optimal solution for this model.

# %%
# The problem is solved using PuLP's choice of Solver
workshop_model.solve()

# The status of the solution is printed to the screen
print( "Status:", pulp.LpStatus[workshop_model.status]     )   
print()
# Out:
# Status: Optimal

# %% [markdown]
# Lastly, we can print the resulting workshop-student assignments.

# %%
#############################################
# show solution

for workshop in rworkshops:
    if pulp.value(offered[workshop])==1:
        sum=0
        for student in rstudents:
            sum+=pulp.value(placement[student][workshop])
        print( "Workshop ", workshop, workshop_names[workshop],", ", sum, " assigned students:")
        for student in rstudents:
            if pulp.value(placement[student][workshop])==1:
                print( "    ", student_names[student], "(Choice: ", preferences[student][workshop],")")
# Out:
# Workshop  1 Sim ,  11.0  assigned students:
#      Eupithes (Choice:  1.0 )
#      Calypso (Choice:  2.0 )
#      Eumaeus (Choice:  1.0 )
#      Melanthius (Choice:  1.0 )
#      Laertes (Choice:  1.0 )
#      Orestes  (Choice:  1.0 )
#      Circe (Choice:  3.0 )
#      Penelope (Choice:  2.0 )
#      Poseiden (Choice:  0.0 )
#      Hermes  (Choice:  1.0 )
#      Siren (Choice:  1.0 )
# Workshop  3 Python ,  9.0  assigned students:
#      Outis (Choice:  3.0 )
#      Odysseus (Choice:  1.0 )
#      Tiresias (Choice:  2.0 )
#      Polyphemus (Choice:  2.0 )
#      Athena (Choice:  0.0 )
#      Anticleia  (Choice:  2.0 )
#      Philoetius (Choice:  2.0 )
#      Scylla (Choice:  2.0 )
#      Agamemnon (Choice:  1.0 )
# Workshop  4 Viz ,  10.0  assigned students:
#      Alcinous (Choice:  1.0 )
#      Menelaus (Choice:  1.0 )
#      Charybdis (Choice:  1.0 )
#      Nausicaa (Choice:  1.0 )
#      Zeus (Choice:  1.0 )
#      Melantho  (Choice:  0.0 )
#      Telemarchus (Choice:  1.0 )
#      Polyphemus  (Choice:  2.0 )
#      Eurycleia (Choice:  2.0 )
#      Aeolus (Choice:  2.0 )

# %% [markdown]
# ## Results

# %% [markdown]
# The optimal solution from our model was used to place people to workshops optimizing their preference level. Since there are over seven students per course, we can see that all of the students are assigned to their top choice amoung the selected options.
#
# We should acknowledge that we have used simpler methods to determine which courses to hold. For example, we could have asked people to vote for their top choice only to determine which three workshops to hold before assigning students. This is equivalent to counting the number of times each workshop was assigned a rank of one. In our data, this would lead to picking Sim and Viz, but then there would be a three-way-tie for the last pick between R Stats, API's, and NLP. Python actually has the least number of people indicating it as their top choice, but several people indicating it as their second choice in the final solution. Using optimization, we can see a solution that meets our needs that might not have been obvious otherwise. Plus, this way gave us a reason to learn more about Python, PuLP, and optimization!
